# %%
import ROOT
from ROOT import TColor
import macro
import matplotlib.pyplot as plt
from IPython.display import Image


# ROOT plots can be interactive in the notebook. We have to enable a module called JsMVA.
# Out:
# Welcome to JupyROOT 6.22/03

# %%
#%jsroot on

# %%
# %jsmva on
# Out:
#     <script type="text/javascript">
#         require.config({
#             paths: {
#                 'JsMVA':'https://root.cern.ch/js/jsmva/latest/js/JsMVA.min'
#             }
#         });
#     </script>
#     <link rel="stylesheet" href="https://root.cern.ch/js/jsmva/latest/css/TMVAHTMLOutput.min.css"></link>

# %%
macro.Plot_Input_Variables()

# %%
ROOT.TFile("Input_Variables.root").Get("c1").Draw()

# %%
ROOT.TFile("CorrelationMatrixS.root").Get("CorrelationMatrixS").Draw()
ROOT.TFile("CorrelationMatrixB.root").Get("CorrelationMatrixB").Draw()

# %%
ROOT.TFile("ClassifierOutputBDT.root").Get("canvas1").Draw()
ROOT.TFile("ClassifierOutputMLP.root").Get("canvas2").Draw()

# %%
ROOT.TFile("CutBDT.root").Get("canvas2").Draw()
ROOT.TFile("CutMLP.root").Get("canvas3").Draw()
# Out:
# <table class='tmva_output_table'></table>
# Error in <TList::Clear>: A list is accessing an object (0x82697c0) already deleted (list name = TList)

# %%
ROOT.TFile("ROC.root").Get("c").Draw()
# Out:
# <table class='tmva_output_table'></table>
# libpng error: invalid screen gamma in png_set_gamma

# %%
ROOT.TMVA.network("dataset", "TMVA_output.root")
# Out:
# <table class='tmva_output_table'><tr><td>--- Opening root file TMVA_output.root in read mode</td></tr><tr><td>--- Found directory: Method_MLP</td></tr><tr><td>--- Found 2 instance(s) of the method MLP</td></tr><tr><td>TH2F----1----weights_hist</td></tr><tr><td>weights_hist01----weights_hist</td></tr><tr><td>TH2F----1----weights_hist</td></tr><tr><td>weights_hist12----weights_hist</td></tr><tr><td>--- --------------------------------------------------------------------</td></tr><tr><td>--- If you want to save the image as eps, gif or png, please comment out </td></tr><tr><td>--- the corresponding lines (line no. 239-241) in tmvaglob.C</td></tr><tr><td>--- --------------------------------------------------------------------</td></tr></table>
# Error in <TList::Clear>: A list is accessing an object (0x81e54a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x822cff0) already deleted (list name = TList)
# ...

# %% [markdown]
# <img src="dataset/plots/network.png" width= 70%/>

# %% [markdown]
# <img src="dataset/plots/BDT_0.png" width= 70%/>
